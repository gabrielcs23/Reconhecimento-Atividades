# %%
import pandas as pd

from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('dataset.csv')
X = df.drop(columns=['Activity'])
y = df['Activity']

# balanced_accuracy = (recall + specificity) / 2
# roc_auc_ovr = ROC AUC OneVsRest (sensitive to class imbalance)
# roc_auc_ovo = ROC AUC OneVsOne (insensitive to class imbalance)
metrics = ['f1_weighted', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'accuracy']

# %% [markdown]
# ## KNN

# %%
knn_results = []

# KNN classifiers with odd K in range of (1,19)
# search for best K
for i in range(10):
    k = i*2+1
    knnClass = KNeighborsClassifier(n_neighbors=k, n_jobs=-1)
    result = cross_validate(knnClass, X, y, cv=10, scoring=metrics,
                            return_train_score=True, n_jobs=-1)
    knn_results.append(result)
    print("k = " + str(k) + ":")

    print("\tf1:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_f1_weighted').mean()*100,
                std = result.get('test_f1_weighted').std()))

    print("\tROC AUC OneVsRest:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_roc_auc_ovr_weighted').mean()*100,
                std = result.get('test_roc_auc_ovr_weighted').std()))

    print("\tROC AUC OneVsOne:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_roc_auc_ovo_weighted').mean()*100,
                std = result.get('test_roc_auc_ovo_weighted').std()))

    print("\tbalanced accuracy:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_balanced_accuracy').mean()*100,
                std = result.get('test_balanced_accuracy').std()))

    print("\taccuracy:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
          .format(mean = result.get('test_accuracy').mean()*100,
                  std = result.get('test_accuracy').std()))

# spoiler it's: 9
# Out:
# k = 1:
# 	f1:
# 		mean = 88.31%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 93.20%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 91.65%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 81.40%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 88.39%;
# 		std = 0.02;
# k = 3:
# 	f1:
# 		mean = 89.76%;
# 		std = 0.01;
# 	ROC AUC OneVsRest:
# 		mean = 97.47%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 96.88%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 81.95%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 89.86%;
# 		std = 0.01;
# k = 5:
# 	f1:
# 		mean = 90.06%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 98.36%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 98.07%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 82.00%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 90.15%;
# 		std = 0.02;
# k = 7:
# 	f1:
# 		mean = 90.19%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 98.73%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 98.48%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 83.17%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 90.29%;
# 		std = 0.02;
# k = 9:
# 	f1:
# 		mean = 90.41%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 98.94%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 98.73%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 82.86%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 90.52%;
# 		std = 0.02;
# k = 11:
# 	f1:
# 		mean = 90.21%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 99.06%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 98.87%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 82.27%;
# 		std = 0.04;
# 	accuracy:
# 		mean = 90.31%;
# 		std = 0.02;
# k = 13:
# 	f1:
# 		mean = 90.18%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 99.13%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 99.03%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 81.45%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 90.29%;
# 		std = 0.02;
# k = 15:
# 	f1:
# 		mean = 90.12%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 99.16%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 99.09%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 80.60%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 90.24%;
# 		std = 0.02;
# k = 17:
# 	f1:
# 		mean = 90.08%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 99.19%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 99.11%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 79.90%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 90.22%;
# 		std = 0.02;
# k = 19:
# 	f1:
# 		mean = 90.15%;
# 		std = 0.02;
# 	ROC AUC OneVsRest:
# 		mean = 99.21%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 99.13%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 79.35%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 90.30%;
# 		std = 0.02;

# %% [markdown]
# ## KNN report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, train_size=0.7, random_state=42)
knn = KNeighborsClassifier(n_neighbors=9, n_jobs=-1)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# skf = StratifiedKFold(n_splits=10)
# for train_index, test_index in skf.split(X, y):
#     X_train, X_test = X.values[train_index], X.values[test_index]
#     y_train, y_test = y[train_index], y[test_index]
#     knn = KNeighborsClassifier(n_neighbors=9, n_jobs=-1)
#     knn.fit(X_train, y_train)
#     y_pred = knn.predict(X_test)
#     report = classification_report(y_test, y_pred)
#     print(report)
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       0.99      1.00      0.99       587
#         LIE_TO_SIT       0.65      0.77      0.70        26
#       LIE_TO_STAND       0.69      0.44      0.54        25
#            SITTING       0.89      0.88      0.89       540
#         SIT_TO_LIE       0.62      0.88      0.73        32
#       SIT_TO_STAND       1.00      0.90      0.95        10
#           STANDING       0.91      0.90      0.91       594
#       STAND_TO_LIE       0.90      0.62      0.73        42
#       STAND_TO_SIT       0.85      0.52      0.65        21
#            WALKING       0.99      1.00      1.00       517
# WALKING_DOWNSTAIRS       1.00      0.99      0.99       422
#   WALKING_UPSTAIRS       0.96      1.00      0.98       463
#
#           accuracy                           0.94      3279
#          macro avg       0.87      0.82      0.84      3279
#       weighted avg       0.95      0.94      0.94      3279

# %% [markdown]
# ## Decision Tree

# %%
tree_results = []

# Search for the best tree depth
for i in range(1, 17):
    curr = DecisionTreeClassifier(random_state=42, max_depth=i)
    result = cross_validate(curr, X, y, cv=10, scoring=metrics,
                            return_train_score=True, n_jobs=-1)
    tree_results.append(result)
    print("Depth = " + str(i) + ":")

    print("\tf1:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_f1_weighted').mean()*100,
                std = result.get('test_f1_weighted').std()))

    print("\tROC AUC OneVsRest:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_roc_auc_ovr_weighted').mean()*100,
                std = result.get('test_roc_auc_ovr_weighted').std()))

    print("\tROC AUC OneVsOne:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_roc_auc_ovo_weighted').mean()*100,
                std = result.get('test_roc_auc_ovo_weighted').std()))

    print("\tbalanced accuracy:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
        .format(mean = result.get('test_balanced_accuracy').mean()*100,
                std = result.get('test_balanced_accuracy').std()))

    print("\taccuracy:")
    print("\t\tmean = {mean:.2f}%;\n\t\tstd = {std:.2f};"
          .format(mean = result.get('test_accuracy').mean()*100,
                  std = result.get('test_accuracy').std()))

# spoiler it's 10
# Out:
# Depth = 1:
# 	f1:
# 		mean = 24.16%;
# 		std = 0.00;
# 	ROC AUC OneVsRest:
# 		mean = 67.26%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 62.27%;
# 		std = 0.00;
# 	balanced accuracy:
# 		mean = 16.53%;
# 		std = 0.00;
# 	accuracy:
# 		mean = 35.72%;
# 		std = 0.00;
# Depth = 2:
# 	f1:
# 		mean = 38.03%;
# 		std = 0.00;
# 	ROC AUC OneVsRest:
# 		mean = 86.65%;
# 		std = 0.00;
# 	ROC AUC OneVsOne:
# 		mean = 80.71%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 25.44%;
# 		std = 0.01;
# 	accuracy:
# 		mean = 51.50%;
# 		std = 0.00;
# Depth = 3:
# 	f1:
# 		mean = 66.63%;
# 		std = 0.04;
# 	ROC AUC OneVsRest:
# 		mean = 92.91%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 86.31%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 37.48%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 72.28%;
# 		std = 0.03;
# Depth = 4:
# 	f1:
# 		mean = 78.11%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 95.26%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 91.26%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 42.10%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 79.82%;
# 		std = 0.03;
# Depth = 5:
# 	f1:
# 		mean = 79.21%;
# 		std = 0.04;
# 	ROC AUC OneVsRest:
# 		mean = 96.48%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 95.13%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 48.28%;
# 		std = 0.05;
# 	accuracy:
# 		mean = 80.15%;
# 		std = 0.04;
# Depth = 6:
# 	f1:
# 		mean = 81.57%;
# 		std = 0.04;
# 	ROC AUC OneVsRest:
# 		mean = 96.77%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 95.45%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 56.83%;
# 		std = 0.04;
# 	accuracy:
# 		mean = 82.09%;
# 		std = 0.04;
# Depth = 7:
# 	f1:
# 		mean = 83.94%;
# 		std = 0.04;
# 	ROC AUC OneVsRest:
# 		mean = 96.40%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 95.30%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 62.67%;
# 		std = 0.04;
# 	accuracy:
# 		mean = 84.23%;
# 		std = 0.04;
# Depth = 8:
# 	f1:
# 		mean = 84.66%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 95.86%;
# 		std = 0.01;
# 	ROC AUC OneVsOne:
# 		mean = 94.99%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 67.55%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 84.78%;
# 		std = 0.03;
# Depth = 9:
# 	f1:
# 		mean = 85.12%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 94.59%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 93.47%;
# 		std = 0.01;
# 	balanced accuracy:
# 		mean = 70.12%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 85.29%;
# 		std = 0.03;
# Depth = 10:
# 	f1:
# 		mean = 85.60%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 93.50%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 91.56%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 72.87%;
# 		std = 0.02;
# 	accuracy:
# 		mean = 85.68%;
# 		std = 0.03;
# Depth = 11:
# 	f1:
# 		mean = 85.56%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 92.73%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 90.11%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 71.85%;
# 		std = 0.04;
# 	accuracy:
# 		mean = 85.63%;
# 		std = 0.03;
# Depth = 12:
# 	f1:
# 		mean = 85.22%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 91.74%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 88.99%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 71.93%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 85.30%;
# 		std = 0.03;
# Depth = 13:
# 	f1:
# 		mean = 85.07%;
# 		std = 0.04;
# 	ROC AUC OneVsRest:
# 		mean = 91.58%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 88.92%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 72.79%;
# 		std = 0.04;
# 	accuracy:
# 		mean = 85.13%;
# 		std = 0.03;
# Depth = 14:
# 	f1:
# 		mean = 84.80%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 90.99%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 88.01%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 71.26%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 84.81%;
# 		std = 0.03;
# Depth = 15:
# 	f1:
# 		mean = 84.96%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 91.32%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 88.25%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 71.89%;
# 		std = 0.04;
# 	accuracy:
# 		mean = 85.06%;
# 		std = 0.03;
# Depth = 16:
# 	f1:
# 		mean = 84.87%;
# 		std = 0.03;
# 	ROC AUC OneVsRest:
# 		mean = 91.11%;
# 		std = 0.02;
# 	ROC AUC OneVsOne:
# 		mean = 88.08%;
# 		std = 0.02;
# 	balanced accuracy:
# 		mean = 71.84%;
# 		std = 0.03;
# 	accuracy:
# 		mean = 84.95%;
# 		std = 0.03;

# %% [markdown]
# ## Decision Tree Report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, train_size=0.7, random_state=42)
dtree = DecisionTreeClassifier(random_state=42, max_depth=10)
dtree.fit(X_train, y_train)
y_pred = dtree.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# skf = StratifiedKFold(n_splits=10)
# for train_index, test_index in skf.split(X, y):
#     X_train, X_test = X.values[train_index], X.values[test_index]
#     y_train, y_test = y[train_index], y[test_index]
#     dtree = DecisionTreeClassifier(random_state=42, max_depth=10)
#     dtree.fit(X_train, y_train)
#     y_pred = dtree.predict(X_test)
#     report = classification_report(y_test, y_pred)
#     print(report)
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       0.98      0.99      0.98       587
#         LIE_TO_SIT       0.62      0.58      0.60        26
#       LIE_TO_STAND       0.61      0.56      0.58        25
#            SITTING       0.89      0.90      0.90       540
#         SIT_TO_LIE       0.57      0.75      0.65        32
#       SIT_TO_STAND       0.30      0.30      0.30        10
#           STANDING       0.91      0.91      0.91       594
#       STAND_TO_LIE       0.71      0.48      0.57        42
#       STAND_TO_SIT       0.64      0.33      0.44        21
#            WALKING       0.93      0.92      0.93       517
# WALKING_DOWNSTAIRS       0.91      0.93      0.92       422
#   WALKING_UPSTAIRS       0.90      0.91      0.91       463
#
#           accuracy                           0.91      3279
#          macro avg       0.75      0.71      0.72      3279
#       weighted avg       0.91      0.91      0.91      3279
